# %%
import slab
from slab import *
import h5py
from h5py import File
from matplotlib import pyplot as plt
os.chdir('S:\\_Furnace\\Furnace_Data\\')
# %matplotlib notebook
# Out:
# Warning could not load Chase AWG dll, check that dll located at 'C:\_Lib\python\slab\instruments\awg\chase\dax22000_lib_DLL32.dll'
# C:\Users\Molybdenum\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\qt.py:13: ShimWarning: The `IPython.qt` package has been deprecated since IPython 4.0. You should import from qtconsole instead.
#   "You should import from qtconsole instead.", ShimWarning)
# Could not load InstrumentManagerWindow
# Warning could not load LDA labbrick dll, check that dll located at 'C:\_Lib\python\slab\instruments\labbrick\VNX_atten.dll'
# Warning could not load LMS labbrick dll, check that dll located at 'C:\_Lib\python\slab\instruments\labbrick\vnx_fmsynth.dll'
# Warning could not load LPS labbrick dll, check that dll located at 'C:\_Lib\python\slab\instruments\labbrick\VNX_dps.dll'
# Could not load labbrick

# %%
fnum='00005'
prefix='_2019-06-07_Furnace_log'
suffix='.h5'

with File(fnum+prefix+suffix, 'r') as f:
    tpts=np.array(f['tpts']-f['tpts'][0])
    volts=np.array(f['volts'])
    curr=np.array(f['curr'])
    pp_vals={}
    keys = [key for key in f.keys()]
    for vals in keys:
        if vals!='tpts' and vals!='volts' and vals!='curr' and vals!='fil_state':
            pp_vals[vals]=np.array(f[vals])
            

fig, ax=plt.subplots(figsize=(10,6))
for key in iter(pp_vals.keys()):
    plt.semilogy(tpts, pp_vals[key], label=key)
ax.set_ylim([5E-11,1E-2])

ax.set_xlabel('Elapsed Time (Seconds)')
ax.set_ylabel('Pressure (mbar)')

ax2 = ax.twinx()


plt.title('Pressure and Applied Power vs Time log: %s'%fnum+prefix)

ax2.plot(tpts, volts*curr, '-c', linewidth=3, label='Measured Coil Power')

ax2.set_ylabel('Applied Power (Watts)', color='c')
ax2.tick_params(axis='y', labelcolor='c')
ax.legend(loc=2)
plt.xlim([0,tpts[-1]+100])
plt.savefig(fnum+prefix+".png", bbox_inches='tight',dpi=500)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
os.chdir('S:\\_Furnace\\Furnace_Data\\')
fnum='00019'
prefix='_2019-06-07_Furnace_log'
suffix='.h5'

with File(fnum+prefix+suffix, 'r') as f:
    tpts=np.array(f['tpts']-f['tpts'][0])
    volts=np.array(f['volts'])
    curr=np.array(f['curr'])
    pp_vals={}
    keys = [key for key in f.keys()]
    for vals in keys:
        if vals!='tpts' and vals!='volts' and vals!='curr' and vals!='fil_state':
            pp_vals[vals]=np.array(f[vals])
            

fig, ax=plt.subplots(figsize=(10,6))
for key in iter(pp_vals.keys()):
    plt.semilogy(tpts, pp_vals[key], label=key)
ax.set_ylim([5E-11,1E-2])

ax.set_xlabel('Elapsed Time (Seconds)')
ax.set_ylabel('Pressure (mbar)')

ax2 = ax.twinx()


plt.title('Pressure and Applied Power vs Time log: %s'%fnum+prefix)

ax2.plot(tpts, volts*curr, '-c', linewidth=3, label='Measured Coil Power')

ax2.set_ylabel('Applied Power (Watts)', color='c')
ax2.tick_params(axis='y', labelcolor='c')
ax.legend(loc=2)
plt.xlim([0,tpts[-1]+100])
plt.savefig(fnum+prefix+".png", bbox_inches='tight',dpi=500)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
os.chdir('S:\\_Furnace\\Test_data\\')

fnum='00001'
prefix='_2019-06-12_Furnace_log'
suffix='.h5'

with File(fnum+prefix+suffix, 'r') as f:
    tpts=np.array(f['tpts']-f['tpts'][0])
    volts=np.array(f['volts'])
    curr=np.array(f['curr'])
    pp_vals={}
    keys = [key for key in f.keys()]
    for vals in keys:
        if vals!='tpts' and vals!='volts' and vals!='curr' and vals!='fil_state':
            pp_vals[vals]=np.array(f[vals])
            

fig, ax=plt.subplots(figsize=(10,6))
for key in iter(pp_vals.keys()):
    plt.semilogy(tpts/3600, pp_vals[key], label=key)
ax.set_ylim([5E-11,1E-2])

ax.set_xlabel('Elapsed Time (Hours)')
ax.set_ylabel('Pressure (mbar)')

ax2 = ax.twinx()


plt.title('Pressure and Applied Power vs Time log: %s'%fnum+prefix)

ax2.plot(tpts/3600, volts*curr, '-c', linewidth=3, label='Measured Coil Power')

ax2.set_ylabel('Applied Power (Watts)', color='c')
ax2.tick_params(axis='y', labelcolor='c')
ax.legend(loc=2)
plt.xlim([0,(tpts[-1]+100)/3600])
#plt.savefig(fnum+prefix+".png", bbox_inches='tight',dpi=500)

# %%
os.chdir('S:\\_Furnace\\Test_data\\')

fnum='00003'
prefix='_2019-08-08_Furnace_log'
suffix='.h5'

with File(fnum+prefix+suffix, 'r') as f:
    tpts=np.array(f['tpts']-f['tpts'][0])
    volts=np.array(f['volts'])
    curr=np.array(f['curr'])
    pp_vals={}
    keys = [key for key in f.keys()]
    for vals in keys:
        if vals!='tpts' and vals!='volts' and vals!='curr' and vals!='fil_state':
            pp_vals[vals]=np.array(f[vals])
            

fig, ax=plt.subplots(figsize=(10,6))
for key in iter(pp_vals.keys()):
    plt.semilogy(tpts/3600, pp_vals[key], label=key)
ax.set_ylim([5E-11,1E-2])

ax.set_xlabel('Elapsed Time (Hours)')
ax.set_ylabel('Pressure (mbar)')

ax2 = ax.twinx()


plt.title('Pressure and Applied Power vs Time log: %s'%fnum+prefix)

ax2.plot(tpts/3600, volts*curr, '-c', linewidth=3, label='Measured Coil Power')

ax2.set_ylabel('Applied Power (Watts)', color='c')
ax2.tick_params(axis='y', labelcolor='c')
ax.legend(loc=2)
plt.xlim([0,(tpts[-1]+100)/3600])
plt.savefig(fnum+prefix+".png", bbox_inches='tight',dpi=500)
plt.grid()
print(max(volts*curr))
print(max(pp_vals['H2']))
# Out:
# <img src="data:image/png;base64,..." width="1000">
# 373.882093
# 5.955459515620381e-06

# %%
fig, ax=plt.subplots(figsize=(10,6))
for key in iter(pp_vals.keys()):
    plt.semilogy(tpts/3600, pp_vals[key], label=key)
ax.set_ylim([5E-11,1E-2])

ax.set_xlabel('Elapsed Time (Hours)')
ax.set_ylabel('Pressure (mbar)')

# ax2 = ax.twinx()


# plt.title('Pressure and Applied Power vs Time log: %s'%fnum+prefix)

# ax2.plot(tpts/3600, volts*curr, '-c', linewidth=3, label='Measured Coil Power')

# ax2.set_ylabel('Applied Power (Watts)', color='c')
# ax2.tick_params(axis='y', labelcolor='c')
ax.legend(loc=2)
plt.xlim([0,(tpts[-1]+100)/3600])
plt.savefig(fnum+prefix+".png", bbox_inches='tight',dpi=500)
plt.grid()
# Out:
# <img src="data:image/png;base64,..." width="998.8889153504084">

# %%
os.chdir('S:\\_Furnace\\Test_data\\')

fnum='00000'
prefix='_2020-01-19_Furnace_log'
suffix='.h5'

with File(fnum+prefix+suffix, 'r') as f:
    tpts=np.array(f['tpts']-f['tpts'][0])
    volts=np.array(f['volts'])
    curr=np.array(f['curr'])
    temp=np.array(f['cav_temp'])
    pp_vals={}
    keys = [key for key in f.keys()]
    for vals in keys:
        if vals!='tpts' and vals!='volts' and vals!='curr' and vals!='fil_state' and vals!='cav_temp' and vals!='p_tot_mano':
            pp_vals[vals]=np.array(f[vals])
            

fig, ax=plt.subplots(figsize=(10,6))
for key in iter(pp_vals.keys()):
    plt.semilogy(tpts/3600, pp_vals[key], label=key)
    
#plt.semilogy(tpts/3600, pp_vals['p_tot_compound'])
ax.set_ylim([5E-11,5E-2])

ax.set_xlabel('Elapsed Time (Hours)')
ax.set_ylabel('Pressure (mbar)')

ax2 = ax.twinx()


plt.title('Pressure and Applied Power vs Time log: %s'%fnum+prefix)

plt.plot(tpts/3600, volts*curr, label='Applied Coil Power')

ax2.set_ylabel('Applied Power (Watts)', color='c')
ax2.tick_params(axis='y', labelcolor='c')
ax.legend(loc=2)
plt.xlim([0,(tpts[-1]+100)/3600])
plt.savefig(fnum+prefix+".png", bbox_inches='tight',dpi=500)
plt.grid()

plt.figure(figsize=(10,6))
plt.plot(tpts/3600, temp, label='Applied Coil Power')
plt.legend()
plt.xlabel('Elapsed Time (Hours)')
plt.ylabel('Temperature (C)')
plt.grid()
#plt.savefig(fnum+prefix+"_temp"+ ".png", bbox_inches='tight',dpi=500)
print(max(volts*curr))
max(pp_vals['H2'])
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# 390.17722999999995
# 2.2846102631323144e-06

# %%
os.chdir('S:\\_Furnace\\Test_data\\')

fnum='00000'
prefix='_2020-02-21_Furnace_log'
suffix='.h5'

with File(fnum+prefix+suffix, 'r') as f:
    tpts=np.array(f['tpts']-f['tpts'][0])
    volts=np.array(f['volts'])
    curr=np.array(f['curr'])
    temp=np.array(f['cav_temp'])
    pp_vals={}
    keys = [key for key in f.keys()]
    for vals in keys:
        if vals!='tpts' and vals!='volts' and vals!='curr' and vals!='fil_state' and vals!='cav_temp' and vals!='p_tot_mano':
            pp_vals[vals]=np.array(f[vals])
            

fig, ax=plt.subplots(figsize=(10,6))
for key in iter(pp_vals.keys()):
    plt.semilogy(tpts/3600, pp_vals[key], label=key)
    
#plt.semilogy(tpts/3600, pp_vals['p_tot_compound'])
ax.set_ylim([5E-11,5E-2])

ax.set_xlabel('Elapsed Time (Hours)')
ax.set_ylabel('Pressure (mbar)')

ax2 = ax.twinx()


plt.title('Pressure and Applied Power vs Time log: %s'%fnum+prefix)

plt.plot(tpts/3600, volts*curr, label='Applied Coil Power')

ax2.set_ylabel('Applied Power (Watts)', color='c')
ax2.tick_params(axis='y', labelcolor='c')
ax.legend(loc=2)
plt.xlim([0,(tpts[-1]+100)/3600])
plt.savefig(fnum+prefix+".png", bbox_inches='tight',dpi=500)
plt.grid()

plt.figure(figsize=(10,6))
plt.plot(tpts/3600, temp, label='Applied Coil Power')
plt.legend()
plt.xlabel('Elapsed Time (Hours)')
plt.ylabel('Temperature (C)')
plt.grid()
#plt.savefig(fnum+prefix+"_temp"+ ".png", bbox_inches='tight',dpi=500)
print(max(pp_vals['H2']))
# Out:
# 1.0141230623785674e-06

# %%
os.chdir('S:\\_Furnace\\Test_data\\')

fnum='00001'
prefix='_2020-01-26_RGA_log'
suffix='.h5'
print(fnum, prefix)

with File(fnum+prefix+suffix, 'r') as f:
    tpts=np.array(f['tpts']-f['tpts'][0])

    temp=np.array(f['cav_temp'])
    pp_vals={}
    keys = [key for key in f.keys()]
    for vals in keys:
        if vals!='tpts' and vals!='volts' and vals!='curr' and vals!='fil_state' and vals!='cav_temp' and vals!='p_tot_mano':
            pp_vals[vals]=np.array(f[vals])
            
os.chdir('S:\\_Furnace\\Test_data\\')


# with File(fnum+prefix+suffix, 'r') as f:
#     tpts_furnace=np.array(f['tpts']-f['tpts'][0])
#     volts=np.array(f['volts'])
#     curr=np.array(f['curr'])

fs=15
            
fig, ax=plt.subplots(figsize=(10,6))
ln=[]
for key in iter(pp_vals.keys()):
    if key=='p_tot':
        key_new='RGA pres'
    elif key=='p_tot_compound':
        key_new='Cold Cathode pres'
    else:
        key_new=key
    ln+=ax.semilogy(tpts/3600, pp_vals[key], label=key_new)

#plt.semilogy(tpts/3600, pp_vals['p_tot_compound'])
ax.set_ylim([5E-11,5E-2])

ax.set_xlabel('Elapsed Time (Hours)', fontsize=fs)
ax.set_ylabel('Pressure (mbar)', fontsize=fs)

ax2 = ax.twinx()


plt.title('P and T vs Time (~725C for 4 Hours)', fontsize=fs)

ln2=ax2.plot(tpts/3600, temp, 'b', label='Cavity Temperature')
lns=ln+ln2
labs=[l.get_label() for l in lns]


ax2.set_ylabel('Temperature (C)', color='b', fontsize=fs)
ax2.tick_params(axis='y', labelcolor='b')
ax2.grid()

ax2.legend(lns,labs, loc=1, prop={'size':fs*.8}, frameon=True)
plt.xlim([0,(tpts[-1]+100)/3600])
#plt.savefig(fnum+prefix+".png", bbox_inches='tight',dpi=500)

ax.tick_params(axis='x', labelsize=fs) 
ax.tick_params(axis='y', labelsize=fs) 
ax2.tick_params(axis='y', labelsize=fs) 
pre=prefix.split('RGA')
plt.savefig("%s%s%s%s.png"%(fnum, pre[0], 'Temps', pre[1]), bbox_inches='tight',dpi=500)
# Out:
# 00001 _2020-01-26_RGA_log

# %%
max(pp_vals['H2'])/pp_vals['H2'][-1]
# Out:
# 42.21625808803426

# %%
print(pp_vals['H2'][-1])
print(tpts[-1]/3600)
# Out:
# 4.9163970808517155e-08
# 6.695617380605803

# %%
I=np.argmax(pp_vals['H2'])
print(pp_vals['H2'][I])
print(tpts[I]/3600)
print(temp[I])
# Out:
# 2.295302318500401e-06
# 2.356315859688653
# 497.052

# %%
5.9/2.28
# Out:
# 2.5877192982456143
